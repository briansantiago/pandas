# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.mpl_style', 'default')
pd.set_option('display.line_width', 5000)
pd.set_option('display.max_columns', 60)

plt.rcParams['figure.figsize'] = (15, 5)
# Out:
# line_width has been deprecated, use display.width instead (currently both are
# identical)
# C:\Users\minho_kim\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2881: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# 2장에서는 또 다른 csv 파일을 살펴보도록 하죠.
#
# 이번 csv파일은 NYC Open Data로부터 얻은 311 서비스 요청 데이터 입니다.
#
# (우리나라로 치면 민원센터 데이터라고 생각하시면 돼요~)

# %%
complaints = pd.read_csv('C:/Users/minho_kim/Downloads/pandas/pandas-cookbook/data/311-service-requests.csv')
# Out:
# C:\Users\minho_kim\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# 분홍색 바탕으로 보니 뭔가 에러가 발생했다는 것을 알 수 있어요.
#
# DtypeWarning: Columns (8) mixed types
# 이것은 모든 항목이 문자열인데 개중에는 정수인 열도 있다는 뜻입니다.
#
# 지금 당장 실습하는데는 문제가 없으니 계속 진행해봅시다.

# %% [markdown]
# ### 2.1 이 안에 뭐가 있을까?
#
# 엄청 큰 DataFrame은 전부 출력되지 않고, 몇 개만 보여줍니다.
#
# 밑에 예제를 보면 1~ 29까지 111039~ 111069 만 보여주는 것을 확인할 수 있어요.
#
# 참고로 이 DataFrame 크기는 111069 rows × 52 columns 입니다.

# %%
complaints
# Out:
#         Unique Key            Created Date             Closed Date Agency                              Agency Name            Complaint Type                                    Descriptor                  Location Type Incident Zip           Incident Address           Street Name      Cross Street 1                    Cross Street 2   Intersection Street 1 Intersection Street 2  Address Type                 City Landmark Facility Type    Status                Due Date Resolution Action Updated Date       Community Board        Borough  X Coordinate (State Plane)  Y Coordinate (State Plane) Park Facility Name   Park Borough  School Name School Number School Region  School Code School Phone Number                                     School Address  School City School State   School Zip School Not Found  School or Citywide Complaint Vehicle Type Taxi Company Borough Taxi Pick Up Location Bridge Highway Name Bridge Highway Direction Road Ramp Bridge Highway Segment Garage Lot Name Ferry D
# ...

# %% [markdown]
# ### 2.2 row(행) 과 column(열) 선택해서 보자구요.
#
# 원하는 column을 선택하려면 다음과 같이 column의 이름을 써야 됩니다.
#
# 'complaint type'이라는 column을 한번 살펴봅시다

# %%
complaints['Complaint Type']
# Out:
# 0          Noise - Street/Sidewalk
# 1                  Illegal Parking
# 2               Noise - Commercial
# 3                  Noise - Vehicle
# 4                           Rodent
# 5               Noise - Commercial
# 6                 Blocked Driveway
# 7               Noise - Commercial
# 8               Noise - Commercial
# 9               Noise - Commercial
# 10        Noise - House of Worship
# 11              Noise - Commercial
# 12                 Illegal Parking
# 13                 Noise - Vehicle
# 14                          Rodent
# 15        Noise - House of Worship
# 16         Noise - Street/Sidewalk
# 17                 Illegal Parking
# 18          Street Light Condition
# 19              Noise - Commercial
# 20        Noise - House of Worship
# 21              Noise - Commercial
# 22                 Noise - Vehicle
# 23              Noise - Commercial
# 24                Blocked Driveway
# 25         Noise - Street/Sidewalk
# 26          Street Light Condition
# ...

# %% [markdown]
# 이번에는 slice를 써서 5개(5행)만 뽑아서 볼까요?
#
# 처음 5행만 자세히 들여다보는 것만으로도 DataFrame을 파악하는데 큰 도움이 돼요.

# %%
complaints[:5]
# Out:
#    Unique Key            Created Date             Closed Date Agency                              Agency Name           Complaint Type                    Descriptor        Location Type Incident Zip  Incident Address      Street Name   Cross Street 1                    Cross Street 2 Intersection Street 1 Intersection Street 2 Address Type      City Landmark Facility Type    Status                Due Date Resolution Action Updated Date Community Board    Borough  X Coordinate (State Plane)  Y Coordinate (State Plane) Park Facility Name Park Borough  School Name School Number School Region  School Code School Phone Number School Address  School City School State   School Zip School Not Found  School or Citywide Complaint Vehicle Type Taxi Company Borough Taxi Pick Up Location Bridge Highway Name Bridge Highway Direction Road Ramp Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name   Latitude  Longitude                                  Location
# ...

# %% [markdown]
# 위 두가지 방법을 합쳐서 'Complaint Type' column의 5 행(row)만 볼 수도 있습니다.

# %%
complaints['Complaint Type'][:5]
# Out:
# 0    Noise - Street/Sidewalk
# 1            Illegal Parking
# 2         Noise - Commercial
# 3            Noise - Vehicle
# 4                     Rodent
# Name: Complaint Type, dtype: object

# %% [markdown]
# slice 위치와 index의 위치를 바꿔도 결과는 같습니다.

# %%
complaints[:5]['Complaint Type']
# Out:
# 0    Noise - Street/Sidewalk
# 1            Illegal Parking
# 2         Noise - Commercial
# 3            Noise - Vehicle
# 4                     Rodent
# Name: Complaint Type, dtype: object

# %% [markdown]
# ### 2.3 이번에는 columns 을(열) 선택해보자고요~
#
# 만약에 'Complaint Type' column과 'Borough' column만 보고 싶을 때는 어떻게 할까요?
#
# 그냥 원하는 column의 이름을 쓰면 됩니다.
#
# pandas 참 쉽죠잉?

# %%
complaints[['Complaint Type', 'Borough']]
# Out:
#                   Complaint Type        Borough
# 0        Noise - Street/Sidewalk         QUEENS
# 1                Illegal Parking         QUEENS
# 2             Noise - Commercial      MANHATTAN
# 3                Noise - Vehicle      MANHATTAN
# 4                         Rodent      MANHATTAN
# 5             Noise - Commercial         QUEENS
# 6               Blocked Driveway         QUEENS
# 7             Noise - Commercial         QUEENS
# 8             Noise - Commercial      MANHATTAN
# 9             Noise - Commercial       BROOKLYN
# 10      Noise - House of Worship       BROOKLYN
# 11            Noise - Commercial      MANHATTAN
# 12               Illegal Parking      MANHATTAN
# 13               Noise - Vehicle          BRONX
# 14                        Rodent       BROOKLYN
# 15      Noise - House of Worship      MANHATTAN
# 16       Noise - Street/Sidewalk  STATEN ISLAND
# 17               Illegal Parking       BROOKLYN
# 18        Street Light Condition       BROOKLYN
# ...

# %% [markdown]
# 10행만 뽑아서 한번 볼까요?

# %%
complaints[['Complaint Type', 'Borough']][:10]
# Out:
#             Complaint Type    Borough
# 0  Noise - Street/Sidewalk     QUEENS
# 1          Illegal Parking     QUEENS
# 2       Noise - Commercial  MANHATTAN
# 3          Noise - Vehicle  MANHATTAN
# 4                   Rodent  MANHATTAN
# 5       Noise - Commercial     QUEENS
# 6         Blocked Driveway     QUEENS
# 7       Noise - Commercial     QUEENS
# 8       Noise - Commercial  MANHATTAN
# 9       Noise - Commercial   BROOKLYN

# %% [markdown]
# ### 'Complaint Type'  column 중에서 어떤 complaint(민원)이 가장 많은지 알아봅시다.
#
# .value_counts()만 쓰면 됩니다.
#
# 참 쉽죠?

# %%
complaints['Complaint Type'].value_counts()
# Out:
# HEATING                                 14200
# GENERAL CONSTRUCTION                     7471
# Street Light Condition                   7117
# DOF Literature Request                   5797
# PLUMBING                                 5373
# PAINT - PLASTER                          5149
# Blocked Driveway                         4590
# NONCONST                                 3998
# Street Condition                         3473
# Illegal Parking                          3343
# Noise                                    3321
# Traffic Signal Condition                 3145
# Dirty Conditions                         2653
# Water System                             2636
# Noise - Commercial                       2578
# ELECTRIC                                 2350
# Broken Muni Meter                        2070
# Noise - Street/Sidewalk                  1928
# Sanitation Condition                     1824
# Rodent                                   1632
# ...

# %% [markdown]
# complaint type (민원) top 10을 알고 싶으면 slice를 쓰면 됩니다.

# %%
complaint_counts = complaints['Complaint Type'].value_counts()
complaint_counts[:10]
# Out:
# HEATING                   14200
# GENERAL CONSTRUCTION       7471
# Street Light Condition     7117
# DOF Literature Request     5797
# PLUMBING                   5373
# PAINT - PLASTER            5149
# Blocked Driveway           4590
# NONCONST                   3998
# Street Condition           3473
# Illegal Parking            3343
# Name: Complaint Type, dtype: int64

# %% [markdown]
# 마지막으로 그래프도 그릴 수 있습니다.

# %%
complaint_counts[:10].plot(kind='bar')
